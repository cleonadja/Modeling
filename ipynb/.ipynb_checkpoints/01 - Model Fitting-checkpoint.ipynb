# %% [markdown]
# # Regression Models

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
#!pip install tqdm

# %%
cd ..
# Out:
# /home/jovyan/Modeling

# %%
run src/load_data.py

# %%
from sklearn.linear_model import Ridge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import Lasso
from sklearn.svm import SVR

# %%
from sklearn.model_selection import train_test_split
X = housing_df.drop('SalePrice', axis=1)
y = housing_df['SalePrice']

# %%
np.random.seed(42)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
X_train
# Out:
#       LotFrontage  LotArea  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  \
# Id
# 488     70.000000    12243       1971          1971         0.0         998
# 1419    71.000000     9204       1963          1963         0.0          25
# 55      60.000000     7134       1955          1955         0.0         384
# 532     60.000000     6155       1920          1999         0.0           0
# 695     51.000000     6120       1936          1950         0.0           0
# 314    150.000000   215245       1965          1965         0.0        1236
# 1328    60.000000     6600       1982          2008         0.0         641
# 110    105.000000    11751       1977          1977       480.0         705
# 1213    50.000000     9340       1941          1950         0.0         344
# 101     70.049958    10603       1977          2001        28.0        1200
# 664     90.000000    10012       1972          1972         0.0         920
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Ridge Regression

# %%
ridge = Ridge()
ridge.fit(X_train, y_train)
ridge.score(X_train, y_train), ridge.score(X_test, y_test)
# Out:
# (0.93272146333459305, 0.88606818080615102)

# %% [markdown]
# ## Lasso Regression

# %%
lasso = Lasso()
lasso.fit(X_train, y_train)
lasso.score(X_train, y_train), lasso.score(X_test, y_test)
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# (0.94578085854320026, 0.86025373589887466)

# %% [markdown]
# ## KNN

# %%
knn = KNeighborsRegressor()
knn.fit(X_train, y_train)
knn.score(X_train, y_train), knn.score(X_test, y_test)
# Out:
# (0.77305404074860262, 0.67471621479986521)

# %% [markdown]
# ## Decision Tree

# %%
dtree = DecisionTreeClassifier()
dtree.fit(X_train, y_train)
dtree.score(X_train, y_train), dtree.score(X_test, y_test)
# Out:
# (1.0, 0.0055096418732782371)

# %% [markdown]
# ## Support Vector Machines

# %%
X = numeric_log_sc_df.drop('SalePrice', axis=1)
y = numeric_log_sc_df['SalePrice']

# %%
np.random.seed(42)

# %%
X_train_sc, X_test_sc, y_train_sc, y_test_sc = train_test_split(X,y)

# %%
svm = SVR()
svm.fit(X_train_sc, y_train_sc)
svm.score(X_train_sc, y_train_sc), svm.score(X_test_sc, y_test_sc)
# Out:
# (0.88597777564560443, 0.81659613910776607)

# %% [markdown]
# Based on above results we can see that this data set scores much better with linear modles such as Ridge and Lasso since the SalePrice of a House can be described in a linear function and is based on various features weighted in a various ways. KNN, Decision Tree do not do a good job at predicting the SalePrice as those models are based on non-linear solutions. SVR, the regressional SVM, has pretty good results when we use the logged and scaled data set.
